# %% [markdown]
# <a href="https://colab.research.google.com/github/Shin-JH8/S-JH-AI/blob/master/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ● 인공지능 서비스 및 제품 분석
# > ## 1. 언어
# >> ### 1) 파파고
# >>> 2016년 10월 16일 개발된 딥러닝 기반의 번역기 이며, Naver Labs에서 자체 개발한 __인공신경망(Artificial Neural Network)__ 기반의 기술이며, 주로 *줄임말, 관용구, 단문에 관하여 우수한 서비스를 제공*하고 있습니다.
# >> ### 2) 구글 번역
# >>> 2007년 구글에서 발표한 무료 번역 서비스로, 현재 세계에서 가장 많이 사용되는 기계번역 서비스이다. 구글 번역기는 알파고에서도 쓰인 딥러닝 기술을 적용 하였으며, 기준 구글 번역의 오류를 58~87%까지 줄였다고 합니다. 구글 번역기에서는 두 언어 간의 __병렬 말뭉치를 기반으로 비교분석하여 번역 결과물을 추출__하는 과정을 거치게 됩니다. 구글 번역에서는 주로 *장문, 복문, 특정 주제와 관련된 글 또는 문장에서 우수한 서비스를 제공*하고 있습니다.
#
# > ## 2. 음성
# >> ### 1) 빅스비
# >>> 삼성전자가 비브 개발진과 협력 해 개발 한 딥러닝 기반의 발전된 삼성전자의 __소프트웨어 인공지능 서비스__입니다. 빅스비는 *터치, 음성, 카메라 촬영 등 여러 입력 수단을 혼합해 이용할 수 있으며, 사물을 인식하는 기술*도 있습니다. 빅스비는 이용 __데이터가 쌓일수록 더 정교해지는 딥러닝 기술을 바탕으로 개발__됐기 때문에, 어느 정도 시간이 지나야 만족할 만한 서비스를 보여줄 수 있다는 아쉬운 점이 남지만 현제는 사용자가 많아짐으로 하여 우수한 서비스를 보여주고 있습니다.
# >> ### 2) 시리
# >>> Siri는 Apple의 iOS와 iPadOS, macOS, watchOS, tvOS 등 Apple의 소프트웨어 탑재 기기들 전반에서 작동하는 __인공지능 개인 비서 응용 프로그램__입니다. 시리는 머신러닝과 인공지능을 통하여 시리의 목소리를 좀 더 자연스럽게 표현 하였으며 사용자의 음성에 대한 데이터베이스를 쌓아서 인식률을 높이는 방법으로 사용자에게 다가가고 있습니다.
#
# > ## 3. 이미지
# >> ### 1) Apple Face ID
# >>> 휴대전화 잠금을 안면 인식을 통하여 해제하는 방식으로 Apple이 Iphon X 부터 도입한 기술 입니다. Face ID의 장점으로는 사용자가 수염을 기르든 각양각색의 안경이나 선글라스를 쓰든, 머리 스타일을 바꾸든, 모자를 쓰든, 화장을 하거나 안하든 머신 러닝을 통해 이를 인식하고 데이터를 업데이트하고 머신러닝 기술을 사용하여 사용할수록 인식률이 높아지며 빨라진다는 점에 있습니다.
#
# > ## 4. 자율주행
# >> ### 1) 테슬라 오토파일럿
# >>> 운전 정보 제공에 동의한 운전자들의 데이터를 이용하여 딥러닝으로 학습시켜서 지속적으로 개선하고 있다. 자율주행기능의 특성을 잘 이해하여 자율주행과 수동운전사이를 전환하며 사용하면 90%이상의 시간을 자율주행으로 운행하며 수동운전보다 훨씬 안전하고 편리하고 재미있는 운전을 할 수 있다.
